# %% [markdown]
# <a href="https://colab.research.google.com/github/pavanbaki/Machine_Learning/blob/main/MatplotandSeaborn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ### Matplotlib
# ### Seaborn

# %%
#Matplotlib - data visualization package or library where we can use numpy and pandas and create graphs

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# IRIS  dataset which is predefined i python package and datasets

data = sns.load_dataset("iris")

# %%
data
# Out:
#      sepal_length  sepal_width  petal_length  petal_width    species
# 0             5.1          3.5           1.4          0.2     setosa
# 1             4.9          3.0           1.4          0.2     setosa
# 2             4.7          3.2           1.3          0.2     setosa
# 3             4.6          3.1           1.5          0.2     setosa
# 4             5.0          3.6           1.4          0.2     setosa
# ..            ...          ...           ...          ...        ...
# 145           6.7          3.0           5.2          2.3  virginica
# 146           6.3          2.5           5.0          1.9  virginica
# 147           6.5          3.0           5.2          2.0  virginica
# 148           6.2          3.4           5.4          2.3  virginica
# 149           5.9          3.0           5.1          1.8  virginica
#
# [150 rows x 5 columns]

# %%
data.head()
# Out:
#    sepal_length  sepal_width  petal_length  petal_width species
# 0           5.1          3.5           1.4          0.2  setosa
# 1           4.9          3.0           1.4          0.2  setosa
# 2           4.7          3.2           1.3          0.2  setosa
# 3           4.6          3.1           1.5          0.2  setosa
# 4           5.0          3.6           1.4          0.2  setosa

# %%
# Matplot

# Line Graph

plt.plot(data['sepal_width'])

plt.show()

# %%
plt.plot(data['sepal_length'])
plt.show()

# %%
plt.plot(data['petal_width'])
plt.show()

# %%
plt.plot(data['petal_length'])
plt.show()

# %%
#Let's give name to X-axis and y-axis

plt.plot(data["petal_length"])
plt.xlabel("Indexes")
plt.ylabel("Petal Length")
plt.show()

# %%
# Title to the graph

plt.plot(data["petal_length"])
plt.xlabel("Indexes")
plt.ylabel("Petal Length")
plt.title("Petal Length Graph")
plt.show()

# %%
plt.plot(data["petal_length"])
plt.xlabel("Indexes")
plt.ylabel("Petal Length")
plt.title("Petal Length",fontsize = 27)
plt.show()

# %%
plt.plot(data["petal_length"],color = "red")
plt.xlabel("Indexes")
plt.ylabel("Petal Length")
plt.title("Petal Length",fontsize = 27)
plt.show()

# %%
plt.plot(data["petal_length"], color = "red")
plt.plot(data["petal_width"], color = "green")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.show()

# %%
plt.plot(data["petal_length"], color = "red", label = "Petal Length")
plt.plot(data["petal_width"], color = "green",label = "Petal Width")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(data["petal_length"], color = "red", label = "Petal Length")
plt.plot(data["petal_width"], color = "green",label = "Petal Width")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(data["petal_length"], color = "red", label = "Petal Length",linestyle = "--")
plt.plot(data["petal_width"], color = "green",label = "Petal Width")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(data["petal_length"], color = "red", label = "Petal Length",linestyle = "--")
plt.plot(data["petal_width"], color = "green",label = "Petal Width", marker= "o")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.plot(data["petal_length"], color = "red", label = "Petal Length",linestyle = "--",linewidth=3)
plt.plot(data["petal_width"], color = "green",label = "Petal Width", marker= "o")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
plt.figure(figsize = (10,5))
plt.grid()
plt.plot(data["petal_length"], color = "red", label = "Petal Length",linestyle = "--",linewidth=3)
plt.plot(data["petal_width"], color = "green",label = "Petal Width", marker= "o")
plt.xlabel("Indexes")
plt.ylabel("Petal Counts")
plt.title("Iris Petal", fontsize = 27)
plt.legend()
plt.show()

# %%
#Seaborn and matplotlib combinly

#tips dataset also available in default in python programming
import seaborn as sns
tips =  sns.load_dataset('tips')
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
# we are creating bar graphs for iris

plt.bar(data['species'],data['petal_length'])
plt.bar(data['species'],data['petal_width'])

plt.show()

# %%
plt.bar(tips["day"],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
plt.barh(tips["day"],tips['total_bill'])
# Out:
# <BarContainer object of 244 artists>

# %%
# Histogram 
plt.hist(tips['total_bill'], edgecolor= "black")
plt.show()

# %%
#Day must be in fixed length

day = tips.groupby('day')['total_bill'].sum().reset_index()

day
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
# Pie Chart

x= tips['day']
y=tips['total_bill']
tips
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]

# %%
x
# Out:
# 0       Sun
# 1       Sun
# 2       Sun
# 3       Sun
# 4       Sun
#        ...
# 239     Sat
# 240     Sat
# 241     Sat
# 242     Sat
# 243    Thur
# Name: day, Length: 244, dtype: category
# Categories (4, object): ['Thur', 'Fri', 'Sat', 'Sun']

# %%
# Day must be fixed length

day=tips.groupby('day')['total_bill'].sum().reset_index()

day
# Out:
#     day  total_bill
# 0  Thur     1096.33
# 1   Fri      325.88
# 2   Sat     1778.40
# 3   Sun     1627.16

# %%
# Pie Chart

x= day['day']
y=day['total_bill']

# %%
explode = [0,0,0,0.1]

plt.pie(y,labels=x,explode = explode,autopct='%1.1f%%',colors=['red','blue','green','yellow'],wedgeprops = {'edgecolor' : 'black'},shadow=True,startangle=90)
plt.show()

# %%
# scatter plot

plt.scatter(tips['total_bill'],tips['tip'])
plt.title("Scatter plot",fontsize=17)
plt.xlabel("Total Bill")
plt.ylabel("Tip")

plt.show()

# %%
tips['size'].value_counts()
# Out:
# 2    156
# 3     38
# 4     37
# 5      5
# 6      4
# 1      4
# Name: size, dtype: int64

# %%
# I wnat to create scatter plot with some color palet

# scatter plot

plt.scatter(tips['total_bill'],tips['tip'],s=100,c=tips['size'])
plt.title("Scatter plot",fontsize=17)
plt.xlabel("Total Bill")
plt.ylabel("Tip")
cbar=plt.colorbar()
cbar.set_label("Size")

plt.show()

# %%
#seaborn 
# to check styles available in seaborn.Use matplotlib library

plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn',
#  'seaborn-bright',
#  'seaborn-colorblind',
#  'seaborn-dark',
#  'seaborn-dark-palette',
#  'seaborn-darkgrid',
#  'seaborn-deep',
#  'seaborn-muted',
#  'seaborn-notebook',
#  'seaborn-paper',
#  'seaborn-pastel',
#  'seaborn-poster',
#  'seaborn-talk',
#  'seaborn-ticks',
#  'seaborn-white',
#  'seaborn-whitegrid',
#  'tableau-colorblind10']

# %%
9# Seabron implementation

plt.style.use('seaborn-white')

gender=sns.countplot(tips['sex'])

plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/_decorators.py:43: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   FutureWarning

# %%
sns.distplot(tips['total_bill'])
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `histplot` (an axes-level function for histograms).
#   warnings.warn(msg, FutureWarning)

# %%
sns.distplot(tips['total_bill'],hist=False)
# Out:
# /usr/local/lib/python3.7/dist-packages/seaborn/distributions.py:2557: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)

# %%
# scatterplot using seaborn

sns.scatterplot(x='total_bill',y='tip',data=tips,hue = 'size', palette= 'summer')

# %%
#swarmplot 
sns.swarmplot(x='sex',y='total_bill',data=tips)

# %%
#strip plot

sns.stripplot(x='day',y='tip',data=tips,hue='sex')

# %%
# Voiline Plot

sns.violinplot(x='day',y='tip',data=tips,hue='sex')

# %%
# Voiline Plot

sns.violinplot(x='day',y='tip',data=tips,hue='sex',split=True)

# %%
#Boxplot 

sns.boxenplot(x='day',y='tip',data=tips,hue='sex')
